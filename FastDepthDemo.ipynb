# %% [markdown]
# # FastDepth Demo
# by: Hagai konkol and Ido Nahum
#
# in this notebook, we will visualize our results.
#
# please make sure you are running on GPU.

# %% [markdown]
# 1) first we begin in cloning our repo.

# %%
# !git clone https://github.com/idonahum/FastDepth.git
# %cd FastDepth

# %% [markdown]
# installing requirements:

# %%
# !sudo apt-get update
# !sudo apt-get install -y libhdf5-serial-dev hdf5-tools
# !pip3 install h5py matplotlib imageio scikit-image opencv-python

# %% [markdown]
# 2) Lets download evaluation dataset:
#
# if dataset fail to download currectly(~950MB) try to make a Factory reset to the notebook and try again.

# %%
# !mkdir nyudepthv2
# %cd nyudepthv2
# !mkdir train
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1mslDJZluqc6tJyUt2pnkUBCxP3CwpWzV' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1mslDJZluqc6tJyUt2pnkUBCxP3CwpWzV" -O val.zip && rm -rf /tmp/cookies.txt
# !unzip val.zip
# %cd ..

# %% [markdown]
# 3) Lets run evaluation

# %% [markdown]
# FastDepth with L1 loss

# %%
# !python3 main.py -mode eval -backbone mobilenet --pretrained FastDepth_L1_Best.pth
from IPython.display import Image, display
display(Image('samples.png'))
display(Image('samplesjet.png'))
# Out:
# Arguments are Namespace(backbone='mobilenet', bsize=8, criterion='l1', epochs=20, gpu=False, learning_rate=0.01, mode='eval', momentum=0.9, pretrained='FastDepth_L1_Best.pth', print_freq=100, resume=None, samples=None, tensorboard_dir='Tensorboard', train_set=None, val_set=None, weight_decay=0.0001, weights_dir='Weights', workers=16)
# Creating dataset... patience.
# Finish loading datasets
# Model found, loading...
# Finished loading
# Evaluating...
# 653/654Evaluation loss: 0.4452356732812132
# Delta1 Accuarcy: 0.7487857115016368
# Time: 0.10624930144085432
# RMSE: 0.5926739071532856

# %% [markdown]
# FastDepthV2 with L1 loss

# %%
# !python3 main.py -mode eval -backbone mobilenetv2 --pretrained FastDepthV2_L1_Best.pth
from IPython.display import Image, display
display(Image('samples.png'))
display(Image('samplesjet.png'))
# Out:
# Arguments are Namespace(backbone='mobilenetv2', bsize=8, criterion='l1', epochs=20, gpu=False, learning_rate=0.01, mode='eval', momentum=0.9, pretrained='FastDepthV2_L1_Best.pth', print_freq=100, resume=None, samples=None, tensorboard_dir='Tensorboard', train_set=None, val_set=None, weight_decay=0.0001, weights_dir='Weights', workers=16)
# Creating dataset... patience.
# Finish loading datasets
# Model found, loading...
# Finished loading
# Evaluating...
# 653/654Evaluation loss: 0.44459737936427834
# Delta1 Accuarcy: 0.7596212709372552
# Time: 0.08691549191781141
# RMSE: 0.5951538535022954

# %% [markdown]
# There are more pretrained models available. if you would like to run them, use the appropiate command as insturcted in our repo.
#
# Hoping you enjoy our visualization!
